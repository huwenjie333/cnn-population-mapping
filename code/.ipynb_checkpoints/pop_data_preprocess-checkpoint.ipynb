# %%
import numpy as np
import pandas as pd
import re,os,time, math
from shutil import copyfile
import matplotlib.pyplot as plt

# %%
raw_df = pd.read_csv('/home/timhu/dfd-pop/data/annos_csv/India_pov_pop_Feb4.csv')

# %% [markdown]
# ## initial cleanup

# %%
df = raw_df[['id','state_id','secc_pop','secc_pop_scaled','area','longitude','latitude']].copy()
df.rename(columns={'id':'village_id'}, inplace=True)
df.tail()
# Out:
#         village_id  state_id  secc_pop  secc_pop_scaled  area  longitude  \
# 567997      567998        35        69        62.300001   NaN        NaN
# 567998      567999        35       201       181.000002   NaN        NaN
# 567999      568000        35       145       129.900001   NaN        NaN
# 568000      568001        35       173       154.800001   NaN        NaN
# 568001      568002        35        62        57.500000   NaN        NaN
#
#         latitude
# 567997       NaN
# 567998       NaN
# 567999       NaN
# 568000       NaN
# 568001       NaN

# %%
# remove rows with missing are/lat/long
df = df[df.area.notnull() & df.longitude.notnull() & df.latitude.notnull()].copy()
df.index = range(len(df))
df.tail()
# Out:
#         village_id  state_id  secc_pop  secc_pop_scaled          area  \
# 564546      567631        34      6737      6049.450048  4.667680e+06
# 564547      567632        34      2260      2035.500015  4.514581e+06
# 564548      567633        34      3942      3527.600028  5.891136e+06
# 564549      567634        34      2521      2269.200016  3.121377e+06
# 564550      567635        34      3197      2873.100021  4.717539e+06
#
#         longitude   latitude
# 564546  79.792090  10.923974
# 564547  79.757279  10.921364
# 564548  79.742833  10.931922
# 564549  79.771553  10.917816
# 564550  79.793871  10.908532

# %% [markdown]
# ## calculate density and class

# %%
# area in units of m2, calculate density as nums/km2
df['pop_density'] = df.secc_pop / (df.area / 10**6)
df['pop_density_log2'] = np.log2(df['pop_density'])
# pool the log2 population < 1 and > 13 into same class
df['pop_density_log2_int'] = np.minimum(np.maximum(np.floor(df['pop_density_log2']),1),13).astype(int)
# shift the class to [0,xx] classes
df['pop_density_class'] = df['pop_density_log2_int'] - df.pop_density_log2_int.min() 
df.sort_values(by='pop_density', ascending=True).head()
# Out:
#         village_id  state_id  secc_pop  secc_pop_scaled          area  \
# 119594      120007         9         1              1.0  1.940134e+08
# 405549      408521        23         1              1.0  1.222436e+08
# 77960        78373         8         5              5.0  2.628823e+08
# 10959        11187         2         1              1.0  5.160061e+07
# 404668      407640        23         1              1.0  4.064323e+07
#
#         longitude   latitude  pop_density  pop_density_log2  \
# 119594  80.279065  28.601952     0.005154         -7.600013
# 405549  75.765053  24.705484     0.008180         -6.933615
# 77960   71.399273  27.280194     0.019020         -5.716345
# 10959   78.337542  32.082006     0.019380         -5.689316
# 404668  81.107643  23.570906     0.024604         -5.344943
#
#         pop_density_log2_int  pop_density_class
# 119594                     1                  0
# 405549                     1                  0
# 77960                      1                  0
# 10959                      1                  0
# 404668                     1                  0

# %%
df.sort_values(by='pop_density', ascending=False).head()
# Out:
#         village_id  state_id  secc_pop  secc_pop_scaled           area  \
# 206070      206483        10       837       727.300006    2392.198184
# 207404      207817        10       354       311.000001    1089.612040
# 338068      340972        21      6540      5800.100041   29983.557719
# 256792      259695        18      3417      2938.000021   15971.948585
# 206008      206421        10     20200     17534.000116  105617.476219
#
#         longitude   latitude    pop_density  pop_density_log2  \
# 206070  86.053348  25.430511  349887.398749         18.416531
# 207404  86.688575  25.077802  324886.277816         18.309575
# 338068  86.982489  21.491403  218119.546097         17.734760
# 256792  92.291220  24.742941  213937.578231         17.706830
# 206008  85.983399  25.484569  191256.226934         17.545147
#
#         pop_density_log2_int  pop_density_class
# 206070                    13                 12
# 207404                    13                 12
# 338068                    13                 12
# 256792                    13                 12
# 206008                    13                 12

# %%
# distribution of density
n, bins, patches = plt.hist(df.pop_density.values, bins=100, range=(0,5000))

# %%
# distribution of log2 density
n, bins, patches = plt.hist(df.pop_density_log2.values, bins=100)

# %%
# distribution of log2 density class
n, bins, patches = plt.hist(df.pop_density_class.values, bins=range(df.pop_density_class.max()+1))

# %%
df.groupby('pop_density_class')['pop_density', 'pop_density_log2'].agg([np.min, np.median, np.max, 'count'])
# Out:
#                    pop_density                                       \
#                           amin        median           amax   count
# pop_density_class
# 0                     0.005154      1.894465       3.999788    3110
# 1                     4.000257      6.016639       7.999902    2915
# 2                     8.000448     12.010077      15.998577    6043
# 3                    16.001224     23.928107      31.999724   12399
# 4                    32.000790     48.358702      63.999680   26185
# 5                    64.002617     97.397873     127.999586   61582
# 6                   128.000519    187.252134     255.999978  119132
# 7                   256.000204    358.792919     511.997632  132695
# 8                   512.000666    705.952117    1023.998035  111593
# 9                  1024.002998   1344.498459    2047.975061   62727
# 10                 2048.050604   2587.299702    4095.977012   19878
# 11                 4096.125672   5188.924331    8188.472983    4701
# 12                 8194.116769  11930.335811  349887.398749    1591
#
#                   pop_density_log2
#                               amin     median       amax   count
# pop_density_class
# 0                        -7.600013   0.921791   1.999924    3110
# 1                         2.000093   2.588958   2.999982    2915
# 2                         3.000081   3.586174   3.999872    6043
# 3                         4.000110   4.580634   4.999988   12399
# 4                         5.000036   5.595704   5.999993   26185
# 5                         6.000059   6.605818   6.999995   61582
# 6                         7.000006   7.548838   8.000000  119132
# 7                         8.000001   8.487008   8.999993  132695
# 8                         9.000002   9.463427   9.999997  111593
# 9                        10.000004  10.392852  10.999982   62727
# 10                       11.000036  11.337231  11.999992   19878
# 11                       12.000044  12.341220  12.999379    4701
# 12                       13.000373  13.542347  18.416531    1591

# %%
df.to_csv('/home/timhu/dfd-pop/data/annos_csv/India_pov_pop_Feb4_density_class.csv')

# %% [markdown]
# ## village area distribution

# %%
# distribution areas in km2
n, bins, patches = plt.hist(df.area.values / (10**6), bins=100, range=(0, 50))

# %%
print('median area (km2):', np.median(df.area.values) / (10**6))
print('mean area (km2):', np.mean(df.area.values) / (10**6))
print('95% percentile area (km2):', np.percentile(df.area.values, 95) / (10**6))
print('99% percentile area (km2):', np.percentile(df.area.values, 99) / (10**6))
# Out:
# median area (km2): 2.37460607655
# mean area (km2): 4.35366365824
# 95% percentile area (km2): 14.381083491
# 99% percentile area (km2): 29.2077828343

# %% [markdown]
# - the raw landsat inputs are 500x500 images with resolution 30m => covered area = 15km x 15km = 225 km2
# - VGG cropped input are 224x224 images => covered area = (224 x 30 / 1000)^2 = 45.2 km2
# - resize input 150x150 images => covered area = (150 x 30 / 1000)^2 = 20.25km2

# %% [markdown]
# ## train/val/test partition

# %%
# 70% train, 20% Val, 10% test
df['partition'] = 'train'
all_ids = df.village_id.values
val_test_ids = np.random.choice(all_ids, int(0.3 * len(all_ids)), replace=False)
test_ids = np.random.choice(val_test_ids, int(0.1 * len(all_ids)), replace=False)
df.loc[df.village_id.isin(val_test_ids),'partition'] = 'val'
df.loc[df.village_id.isin(test_ids),'partition'] = 'test'

# %%
print(len(df[df.partition == 'train']), len(df[df.partition == 'val']), len(df[df.partition == 'test']))
# Out:
# 395186 112910 56455

# %% [markdown]
# ## add tif imge path

# %%
# initialize tif_path column
df['l8_vis_path'] = ''
df['s1_vis_path'] = ''

# input all file names of tif images
with open('/home/timhu/dfd-pop/data/output.txt') as f:
    filenames = f.readlines()
filenames = [x.strip() for x in filenames] 

# check if it is one-to-one map from village_id to tif filename (any other *_village_id.x.tif, x != 0)
l8_median_india_vis = [x for x in filenames if 'l8_median_india_vis' in x]
s1_median_india_vis = [x for x in filenames if 's1_median_india_vis' in x]
print('unique *_village_id.x.tif: ')
print(set([x[-6:] for x in l8_median_india_vis ]), set([x[-6:] for x in s1_median_india_vis ]))
# check if are unique for all rows in df
print('village_id unique:',len(set(df.village_id.values)) == len(df))
# number of villages, and number of tifs
print('all_ids', 'l8_median_india_vis', 's1_median_india_vis')
print(len(all_ids),len(l8_median_india_vis), len(s1_median_india_vis))
# Out:
# unique *_village_id.x.tif:
# {'.0.tif'} {'.0.tif'}
# village_id unique: True
# all_ids l8_median_india_vis s1_median_india_vis
# 564551 385123 564547

# %%
# attach tif file path to df table (takes ~15min)
df = df.sort_values(by='village_id')
all_ids = df.village_id.values
l8_vis_path_array = df.l8_vis_path.values
s1_vis_path_array = df.s1_vis_path.values

for i,f in enumerate(l8_median_india_vis):   
    if i % 10000 == 0:
        print(i)
    p = re.compile('(l8_median_india_vis_500x500_(\d+).0.tif)')
    filename, vid = p.findall(f)[0]
    vid = int(vid)
    if vid in all_ids:
        path = 'l8_median_india_vis/' + filename
        l8_vis_path_array[np.where(all_ids==vid)[0][0]] = path
df.l8_vis_path = l8_vis_path_array

for i,f in enumerate(s1_median_india_vis):
    if i % 10000 == 0:
        print(i)
    p = re.compile('(s1_median_india_vis_500x500_(\d+).0.tif)')
    filename, vid = p.findall(f)[0]
    vid = int(vid)
    if vid in all_ids:
        path = 's1_median_india_vis/' + filename
        s1_vis_path_array[np.where(all_ids==vid)[0][0]] = path
df.s1_vis_path = s1_vis_path_array
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# 124000
# 125000
# 126000
# 127000
# 128000
# 129000
# 130000
# 131000
# 132000
# 133000
# 134000
# 135000
# 136000
# 137000
# 138000
# 139000
# 140000
# 141000
# 142000
# 143000
# 144000
# 145000
# 146000
# 147000
# 148000
# 149000
# 150000
# 151000
# 152000
# 153000
# 154000
# 155000
# 156000
# 157000
# 158000
# 159000
# 160000
# 161000
# 162000
# 163000
# 164000
# 165000
# 166000
# 167000
# 168000
# 169000
# 170000
# 171000
# 172000
# 173000
# 174000
# 175000
# 176000
# 177000
# 178000
# 179000
# 180000
# 181000
# 182000
# 183000
# 184000
# 185000
# 186000
# 187000
# 188000
# 189000
# 190000
# 191000
# 192000
# 193000
# 194000
# 195000
# 196000
# 197000
# 198000
# 199000
# 200000
# 201000
# 202000
# 203000
# 204000
# 205000
# 206000
# 207000
# 208000
# 209000
# 210000
# 211000
# 212000
# 213000
# 214000
# 215000
# 216000
# 217000
# 218000
# 219000
# 220000
# 221000
# 222000
# 223000
# 224000
# 225000
# 226000
# 227000
# 228000
# 229000
# 230000
# 231000
# 232000
# 233000
# 234000
# 235000
# 236000
# 237000
# 238000
# 239000
# 240000
# 241000
# 242000
# 243000
# 244000
# 245000
# 246000
# 247000
# 248000
# 249000
# 250000
# 251000
# 252000
# 253000
# 254000
# 255000
# 256000
# 257000
# 258000
# 259000
# 260000
# 261000
# 262000
# 263000
# 264000
# 265000
# 266000
# 267000
# 268000
# 269000
# 270000
# 271000
# 272000
# 273000
# 274000
# 275000
# 276000
# 277000
# 278000
# 279000
# 280000
# 281000
# 282000
# 283000
# 284000
# 285000
# 286000
# 287000
# 288000
# 289000
# 290000
# 291000
# 292000
# 293000
# 294000
# 295000
# 296000
# 297000
# 298000
# 299000
# 300000
# 301000
# 302000
# 303000
# 304000
# 305000
# 306000
# 307000
# 308000
# 309000
# 310000
# 311000
# 312000
# 313000
# 314000
# 315000
# 316000
# 317000
# 318000
# 319000
# 320000
# 321000
# 322000
# 323000
# 324000
# 325000
# 326000
# 327000
# 328000
# 329000
# 330000
# 331000
# 332000
# 333000
# 334000
# 335000
# 336000
# 337000
# 338000
# 339000
# 340000
# 341000
# 342000
# 343000
# 344000
# 345000
# 346000
# 347000
# 348000
# 349000
# 350000
# 351000
# 352000
# 353000
# 354000
# 355000
# 356000
# 357000
# 358000
# 359000
# 360000
# 361000
# 362000
# 363000
# 364000
# 365000
# 366000
# 367000
# 368000
# 369000
# 370000
# 371000
# 372000
# 373000
# 374000
# 375000
# 376000
# 377000
# 378000
# 379000
# 380000
# 381000
# 382000
# 383000
# 384000
# 385000
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# 124000
# 125000
# 126000
# 127000
# 128000
# 129000
# 130000
# 131000
# 132000
# 133000
# 134000
# 135000
# 136000
# 137000
# 138000
# 139000
# 140000
# 141000
# 142000
# 143000
# 144000
# 145000
# 146000
# 147000
# 148000
# 149000
# 150000
# 151000
# 152000
# 153000
# 154000
# 155000
# 156000
# 157000
# 158000
# 159000
# 160000
# 161000
# 162000
# 163000
# 164000
# 165000
# 166000
# 167000
# 168000
# 169000
# 170000
# 171000
# 172000
# 173000
# 174000
# 175000
# 176000
# 177000
# 178000
# 179000
# 180000
# 181000
# 182000
# 183000
# 184000
# 185000
# 186000
# 187000
# 188000
# 189000
# 190000
# 191000
# 192000
# 193000
# 194000
# 195000
# 196000
# 197000
# 198000
# 199000
# 200000
# 201000
# 202000
# 203000
# 204000
# 205000
# 206000
# 207000
# 208000
# 209000
# 210000
# 211000
# 212000
# 213000
# 214000
# 215000
# 216000
# 217000
# 218000
# 219000
# 220000
# 221000
# 222000
# 223000
# 224000
# 225000
# 226000
# 227000
# 228000
# 229000
# 230000
# 231000
# 232000
# 233000
# 234000
# 235000
# 236000
# 237000
# 238000
# 239000
# 240000
# 241000
# 242000
# 243000
# 244000
# 245000
# 246000
# 247000
# 248000
# 249000
# 250000
# 251000
# 252000
# 253000
# 254000
# 255000
# 256000
# 257000
# 258000
# 259000
# 260000
# 261000
# 262000
# 263000
# 264000
# 265000
# 266000
# 267000
# 268000
# 269000
# 270000
# 271000
# 272000
# 273000
# 274000
# 275000
# 276000
# 277000
# 278000
# 279000
# 280000
# 281000
# 282000
# 283000
# 284000
# 285000
# 286000
# 287000
# 288000
# 289000
# 290000
# 291000
# 292000
# 293000
# 294000
# 295000
# 296000
# 297000
# 298000
# 299000
# 300000
# 301000
# 302000
# 303000
# 304000
# 305000
# 306000
# 307000
# 308000
# 309000
# 310000
# 311000
# 312000
# 313000
# 314000
# 315000
# 316000
# 317000
# 318000
# 319000
# 320000
# 321000
# 322000
# 323000
# 324000
# 325000
# 326000
# 327000
# 328000
# 329000
# 330000
# 331000
# 332000
# 333000
# 334000
# 335000
# 336000
# 337000
# 338000
# 339000
# 340000
# 341000
# 342000
# 343000
# 344000
# 345000
# 346000
# 347000
# 348000
# 349000
# 350000
# 351000
# 352000
# 353000
# 354000
# 355000
# 356000
# 357000
# 358000
# 359000
# 360000
# 361000
# 362000
# 363000
# 364000
# 365000
# 366000
# 367000
# 368000
# 369000
# 370000
# 371000
# 372000
# 373000
# 374000
# 375000
# 376000
# 377000
# 378000
# 379000
# 380000
# 381000
# 382000
# 383000
# 384000
# 385000
# 386000
# 387000
# 388000
# 389000
# 390000
# 391000
# 392000
# 393000
# 394000
# 395000
# 396000
# 397000
# 398000
# 399000
# 400000
# 401000
# 402000
# 403000
# 404000
# 405000
# 406000
# 407000
# 408000
# 409000
# 410000
# 411000
# 412000
# 413000
# 414000
# 415000
# 416000
# 417000
# 418000
# 419000
# 420000
# 421000
# 422000
# 423000
# 424000
# 425000
# 426000
# 427000
# 428000
# 429000
# 430000
# 431000
# 432000
# 433000
# 434000
# 435000
# 436000
# 437000
# 438000
# 439000
# 440000
# 441000
# 442000
# 443000
# 444000
# 445000
# 446000
# 447000
# 448000
# 449000
# 450000
# 451000
# 452000
# 453000
# 454000
# 455000
# 456000
# 457000
# 458000
# 459000
# 460000
# 461000
# 462000
# 463000
# 464000
# 465000
# 466000
# 467000
# 468000
# 469000
# 470000
# 471000
# 472000
# 473000
# 474000
# 475000
# 476000
# 477000
# 478000
# 479000
# 480000
# 481000
# 482000
# 483000
# 484000
# 485000
# 486000
# 487000
# 488000
# 489000
# 490000
# 491000
# 492000
# 493000
# 494000
# 495000
# 496000
# 497000
# 498000
# 499000
# 500000
# 501000
# 502000
# 503000
# 504000
# 505000
# 506000
# 507000
# 508000
# 509000
# 510000
# 511000
# 512000
# 513000
# 514000
# 515000
# 516000
# 517000
# 518000
# 519000
# 520000
# 521000
# 522000
# 523000
# 524000
# 525000
# 526000
# 527000
# 528000
# 529000
# 530000
# 531000
# 532000
# 533000
# 534000
# 535000
# 536000
# 537000
# 538000
# 539000
# 540000
# 541000
# 542000
# 543000
# 544000
# 545000
# 546000
# 547000
# 548000
# 549000
# 550000
# 551000
# 552000
# 553000
# 554000
# 555000
# 556000
# 557000
# 558000
# 559000
# 560000
# 561000
# 562000
# 563000
# 564000

# %%
print(len(df), len(df[df.l8_vis_path != '']), len(df[df.s1_vis_path != '']))
# Out:
# 564551 385123 564547

# %%
df.to_csv('/home/timhu/dfd-pop/data/annos_csv/all_paths_density_labels_564k_Feb10.csv')

# %% [markdown]
# ## Select single state (24)

# %%
df_state24 = df[df.state_id == 24].copy()
# remove rows with missing l8 or s1 paths
df_state24 = df_state24.loc[(df_state24.l8_vis_path != '') & (df_state24.s1_vis_path != '')]
df_state24.index = range(len(df_state24))
df_state24.tail()
# Out:
#        village_id  state_id  secc_pop  secc_pop_scaled          area  \
# 13425      457313        24      1004       888.350008  1.098721e+07
# 13426      457314        24       682       609.700005  3.760594e+06
# 13427      457315        24       759       671.850006  3.853408e+06
# 13428      457316        24       397       352.350003  7.399015e+06
# 13429      457329        24        69        61.750000  1.560559e+06
#
#        longitude   latitude  pop_density  pop_density_log2  \
# 13425  73.331410  21.764242    91.378954          6.513790
# 13426  73.344004  21.773105   181.354324          7.502667
# 13427  73.360595  21.768040   196.968483          7.621821
# 13428  73.379008  21.774119    53.655789          5.745662
# 13429  73.261922  21.776620    44.214914          5.466461
#
#        pop_density_log2_int  pop_density_class partition  \
# 13425                     6                  5     train
# 13426                     7                  6     train
# 13427                     7                  6     train
# 13428                     5                  4       val
# 13429                     5                  4     train
#
#                                              l8_vis_path  \
# 13425  l8_median_india_vis/l8_median_india_vis_500x50...
# 13426  l8_median_india_vis/l8_median_india_vis_500x50...
# 13427  l8_median_india_vis/l8_median_india_vis_500x50...
# 13428  l8_median_india_vis/l8_median_india_vis_500x50...
# 13429  l8_median_india_vis/l8_median_india_vis_500x50...
#
#                                              s1_vis_path
# 13425  s1_median_india_vis/s1_median_india_vis_500x50...
# 13426  s1_median_india_vis/s1_median_india_vis_500x50...
# 13427  s1_median_india_vis/s1_median_india_vis_500x50...
# 13428  s1_median_india_vis/s1_median_india_vis_500x50...
# 13429  s1_median_india_vis/s1_median_india_vis_500x50...

# %%
df_state24.groupby('pop_density_class')['pop_density', 'pop_density_log2'].agg([np.min, np.median, np.max,'count'])
# Out:
#                     pop_density                                    \
#                            amin        median          amax count
# pop_density_class
# 0                      0.049215      2.160701      3.887084    38
# 1                      4.002296      6.187132      7.993654    44
# 2                      8.061444     12.125799     15.796983   118
# 3                     16.326881     24.406190     31.963326   306
# 4                     32.165256     49.424446     63.954584   808
# 5                     64.018905     98.232294    127.962600  2242
# 6                    128.003776    185.347252    255.991622  3940
# 7                    256.100524    351.155396    511.491737  3714
# 8                    512.099036    659.324830   1020.325741  1795
# 9                   1024.311578   1213.483623   2046.708528   356
# 10                  2048.596307   2677.311177   4076.850507    58
# 11                  4138.416533   4848.544328   6274.909245     9
# 12                 10200.176034  11549.536193  12898.896352     2
#
#                   pop_density_log2
#                               amin     median       amax count
# pop_density_class
# 0                        -4.344771   1.111175   1.958688    38
# 1                         2.000828   2.629263   2.998855    44
# 2                         3.011038   3.599998   3.981577   118
# 3                         4.029177   4.609175   4.998346   306
# 4                         5.007431   5.627153   5.998976   808
# 5                         6.000426   6.618125   6.999578  2242
# 6                         7.000043   7.534087   7.999953  3940
# 7                         8.000566   8.455966   8.998567  3714
# 8                         9.000279   9.364846   9.994814  1795
# 9                        10.000439  10.244939  10.999090   356
# 10                       11.000420  11.386568  11.993239    58
# 11                       12.014863  12.243336  12.615379     9
# 12                       13.316306  13.485633  13.654960     2

# %%
# remove village_id with extrme small/big densities
df_state24 = df_state24[(df_state24.pop_density_class >= 3) & (df_state24.pop_density_class <= 9)]
print('total village_id left:', len(df_state24))
# Out:
# total village_id left: 13161

# %%
n, bins, patches = plt.hist(df_state24.pop_density_class.values, bins=range(df.pop_density_class.max()+1))

# %%
df_state24.to_csv('/home/timhu/dfd-pop/data/annos_csv/state24_paths_density_labels_13k_Feb10.csv')

# %% [markdown]
# ## Overlap Removal

# %%
# TODO
# output: state24_paths_density_labels_13k_Feb26-NoOverlapDistrict.csv

# %% [markdown]
# ## create jpg path column in csv

# %%
# run before: jpg_convertion.py

# ANNOS_CSV = '/home/timhu/dfd-pop/data/annos_csv/state24_paths_density_labels_13k_Feb10.csv'
ANNOS_CSV = '/home/timhu/dfd-pop/data/annos_csv/state24_paths_density_labels_13k_Feb26-NoOverlapDistrict.csv'
df_annos = pd.read_csv(ANNOS_CSV, index_col=0)

# %%
df_annos.head()
# Out:
#    village_id  state_id  secc_pop  secc_pop_scaled          area  longitude  \
# 0      442056        24       901       808.950004  6.645771e+06  68.663873
# 1      442057        24       492       427.650002  1.705644e+07  68.699879
# 3      442059        24       288       249.200002  5.765201e+06  68.771516
# 4      442060        24       548       476.600004  1.800210e+07  68.764880
# 5      442061        24       972       846.250010  5.488611e+07  68.834434
#
#     latitude  pop_density  pop_density_log2  pop_density_log2_int  \
# 0  23.787009   135.574930          7.082947                     7
# 1  23.782466    28.845417          4.850270                     4
# 3  23.794030    49.954891          5.642554                     5
# 4  23.817557    30.440892          4.927939                     4
# 5  23.789144    17.709398          4.146443                     4
#
#    pop_density_class partition  \
# 0                  6     train
# 1                  3       val
# 3                  4     train
# 4                  3     train
# 5                  3     train
#
#                                          l8_vis_path  \
# 0  l8_median_india_vis/l8_median_india_vis_500x50...
# 1  l8_median_india_vis/l8_median_india_vis_500x50...
# 3  l8_median_india_vis/l8_median_india_vis_500x50...
# 4  l8_median_india_vis/l8_median_india_vis_500x50...
# 5  l8_median_india_vis/l8_median_india_vis_500x50...
#
#                                          s1_vis_path
# 0  s1_median_india_vis/s1_median_india_vis_500x50...
# 1  s1_median_india_vis/s1_median_india_vis_500x50...
# 3  s1_median_india_vis/s1_median_india_vis_500x50...
# 4  s1_median_india_vis/s1_median_india_vis_500x50...
# 5  s1_median_india_vis/s1_median_india_vis_500x50...

# %%
# df_annos['l8_vis_jpg'] = df_annos.l8_vis_path.str.replace('500x500', '150x150')
# df_annos['l8_vis_jpg'] = df_annos['l8_vis_jpg'].str.replace('tif', 'jpg')

# df_annos['s1_vis_jpg'] = df_annos.s1_vis_path.str.replace('500x500', '450x450')
# df_annos['s1_vis_jpg'] = df_annos['s1_vis_jpg'].str.replace('tif', 'jpg')
# df_annos.to_csv('/home/timhu/dfd-pop/data/annos_csv/state24_jpgpaths_density_nolaps_12k_Mar6.csv')

# %%
len(df_annos)
